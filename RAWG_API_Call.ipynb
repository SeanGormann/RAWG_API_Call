# %%
import requests
import json
import os
import pandas as pd
import time

# %%
API_Key = "5f4e90c75eb6480283ecbbe8b78d66ca"
URL = "https://api.rawg.io/api/games"

# %%
def get_game_info(game):
    game_id = result["id"]
    game_name = result["name"]
    game_release_date = result["released"]
    game_rating = result["rating"]
    game_metacritic = result["metacritic"]
    game_playtime = result["playtime"]
    
    return game_id, game_name, game_release_date, game_rating, game_metacritic, game_playtime

# %%
df = pd.DataFrame(columns=["game_id", "game_name", "game_release_date", "game_rating", \
                           "game_metacritic","game_playtime"])

# %%
j = 0
for i in range(1,100):
    querystring = {"key": API_Key, "page": i}
    try:
        response = requests.request("GET", URL, params=querystring)
    except JSONDecodeError:
        break
    response = response.json()
    for result in response["results"]:
        game_id, game_name, game_release_date, game_rating, game_metacritic, game_playtime = get_game_info(result)
        df = df.append({"game_id": game_id, "game_name": game_name, "game_release_date": game_release_date, \
                        "game_rating": game_rating, "game_metacritic": game_metacritic, \
                        "game_playtime": game_playtime}, ignore_index=True)

# %%
df
# Out:
#      game_id                         game_name game_release_date  game_rating  \
# 0       3498                Grand Theft Auto V        2013-09-17         4.47
# 1       3328          The Witcher 3: Wild Hunt        2015-05-18         4.66
# 2       4200                          Portal 2        2011-04-18         4.62
# 3       5286                Tomb Raider (2013)        2013-03-05         4.05
# 4       4291  Counter-Strike: Global Offensive        2012-08-21         3.56
# ...      ...                               ...               ...          ...
# 3555  545033            Resident Evil Re:Verse        2022-10-28         1.60
# 3556   14101                    Sakura Clicker        2015-07-29         2.54
# 3557   10239            Battlestations: Midway        2007-01-30         2.69
# 3558   20218                     Canyon Capers        2014-04-25         1.87
# 3559   58815                            Nioh 2        2020-03-13         4.09
#
#      game_metacritic game_playtime
# 0                 92            73
# 1                 92            46
# 2                 95            11
# 3                 86            10
# 4                 81            65
# ...              ...           ...
# 3555            None             1
# 3556            None             1
# 3557              76             1
# 3558            None             3
# 3559              85             0
#
# [3560 rows x 6 columns]
