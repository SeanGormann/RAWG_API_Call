# %%
import requests
import json
import os
import pandas as pd
import time 
import plotly.express as px

# %%
API_Key = "-----------"
URL = "https://api.rawg.io/api/games"

# %%
def get_game_info(game):
    game_id = result["id"]
    game_name = result["name"]
    game_release_date = result["released"]
    game_rating = result["rating"]
    game_metacritic = result["metacritic"]
    game_playtime = result["playtime"]
    
    return game_id, game_name, game_release_date, game_rating, game_metacritic, game_playtime

# %%
df = pd.DataFrame(columns=["game_id", "game_name", "game_release_date", "game_rating", \
                           "game_metacritic","game_playtime"])

# %%
j = 0
for i in range(1,100):
    querystring = {"key": API_Key, "page": i}
    try:
        response = requests.request("GET", URL, params=querystring)
        response = response.json()
    except JSONDecodeError:
        break
    for result in response["results"]:
        game_id, game_name, game_release_date, game_rating, game_metacritic, game_playtime = get_game_info(result)
        df = df.append({"game_id": game_id, "game_name": game_name, "game_release_date": game_release_date, \
                        "game_rating": game_rating, "game_metacritic": game_metacritic, \
                        "game_playtime": game_playtime}, ignore_index=True)

# %%
df
# Out:
#      game_id                         game_name game_release_date  game_rating  \
# 0       3498                Grand Theft Auto V        2013-09-17         4.47
# 1       3328          The Witcher 3: Wild Hunt        2015-05-18         4.66
# 2       4200                          Portal 2        2011-04-18         4.62
# 3       5286                Tomb Raider (2013)        2013-03-05         4.05
# 4       4291  Counter-Strike: Global Offensive        2012-08-21         3.56
# ...      ...                               ...               ...          ...
# 1975   51081                        Beholder 2        2018-12-04         3.71
# 1976   28414                           FIFA 12        2011-09-27         3.39
# 1977   20960                          The Plan        2014-02-14         3.25
# 1978   20218                     Canyon Capers        2014-04-25         1.87
# 1979   58815                            Nioh 2        2020-03-13         4.10
#
#      game_metacritic game_playtime
# 0                 92            73
# 1                 92            46
# 2                 95            11
# 3                 86            10
# 4                 81            65
# ...              ...           ...
# 1975              76             5
# 1976              85             0
# 1977              50             1
# 1978            None             3
# 1979              85             0
#
# [1980 rows x 6 columns]

# %%
px.histogram(df, x="game_metacritic", nbins=25, title="Game Rating Distribution")
# Out:
# <div>                            <div id="ed065d56-21a1-40eb-8278-b909c47d176f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed065d56-21a1-40eb-8278-b909c47d176f")) {                    Plotly.newPlot(                        "ed065d56-21a1-40eb-8278-b909c47d176f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"game_metacritic=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":25,"offsetgroup":"","orientation":"v","showlegend":false,"x":[92,92,95,86,81,90,89,94,94,89,83,96,96,96,88,85,84,94,82,92,79,89,95,86,90,81,73,73,79,91,86,81,92,88,null,85,93,86,88,87,90,83,80,88,81,81,85,89,80,83,76,null,87,88,85,83,null,84,96,81,81,79,93,86,80,83,89,87,80,null,81,86,90,76,84,85,91,79,80,94,95,83,86,94,74,null,84,84,80,80,89,75,92,83,74,88,76,86,92,76,84,88,73,89,83,88,89,89,86,80,90,80,80,87,85,91,87,85,77,76,83,87,77,91,82,78,80,77,89,81,87,86,78,83,83,81,89,92,85,93,null,83,90,74,75,72,81,80,82,87,82,88,null,null,81,88,73,80,82,91,70,81,84,86,86,80,78,74,88,null,95,null,86,88,84,76,84,72,90,70,91,65,74,73,79,93,93,74,86,79,73,72,95,92,88,91,83,91,81,82,84,89,86,85,79,null,71,66,88,79,71,84,88,84,85,85,83,87,88,94,91,79,84,71,null,66,83,84,82,63,95,73,62,89,81,70,82,88,77,62,73,86,87,66,85,88,83,82,84,76,80,85,89,81,86,87,80,85,80,72,95
4.21,3.52,4.38,4.4,3.97,3.66,3.96,2.8,4.02,3.68,4.13,4.16,3.42,3.94,4.21,3.97,4.02,3.58,2.61,2.75,4.43,4.06,4.01,3.94,3.73,3.68,4.13,3.21,3.94,2.99,2.65,3.93,3.03,4.3,3.62,3.66,3.72,3.95,4.28,4.1,3.48,3.31,3.18,3.31,4.09,4.41,3.5,3.91,4.29,4.06,4.34,3.62,3.8,4.09,4.22,3.82,4.15,3.05,3.93,2.83,3.7,2.91,4.37,4.39,3.77,3.88,4.24,2.43,4.34,2.42,4.13,2.67,2.88,3.2,2.76,2.98,4.42,3.68,2.62,4.12,4.55,3.22,4.09,3.49,4.39,4.4,2.65,4.15,3.91,3.76,3.45,4.1,3.24,4.15,3.06,3.81,4.02,4.04,3.15,2.66,2.7,3.75,2.68,3.91,4.21,2.56,3.96,2.49,3.18,4.07,3.05,3.9,3.43,3.32,3.98,3.5,3.13,3.33,3.82,4.42,3.75,4.15,3.82,3.48,4.04,3.63,3.69,3.93,3.77,3.75,4.36,2.79,4.04,4.1,3.95,3.95,4.36,3.53,4.08,3.55,3.47,3.76,3.83,3.52,2.35,3.5,3.35,3.84,3.99,3.65,4.22,3.44,4.18,2.92,3.73,2.82,3.22,3.85,3.97,4.32,3.76,3.2,3.42,4.44,3.61,3.35,4.17,4.21,3.94,4.04,3.58,3.53,4.13,3.11,3.74,3.88,3.65,3.18,3.93,3.15,4.07,3.62,3.44,3.86,3.56,4.02,2.47,2.29,4.29,3.23,3.8,2.81,2.88,3.62,2.73,2.71,3.97,3.54,3.89,3.32,3.38,4.15,4.03,2.73,3.88,3.73,4.14,3.98,3.45,4.04,2.89,3.38,3.71,4.32,3.74,3.22,3.6,4.38,4.32,3.35,3.9,3.22,3.25,3.42,3.82,3.93,3.81,3.73,4.11,3.01,3.53,4.06,3.66,4.4,2.92,3.36,3.72,2.61,3.99,3.49,3.7,4.0,4.08,3.9,3.93,3.6,3.55,2.81,3.42,3.17,2.84,3.67,4.56,3.95,4.34,4. ...

# %%
#x.write_image("metacritic_vs_fans.png")

# %%
#x.to_image(format="png")

# %%
#save px scatter plot as png

# %% [markdown]
# # Exporting to a database

# %%
import psycopg2 as ps
import pandas as pd

# %%
df.head()
# Out:
#   game_id                         game_name game_release_date  game_rating  \
# 0    3498                Grand Theft Auto V        2013-09-17         4.47
# 1    3328          The Witcher 3: Wild Hunt        2015-05-18         4.66
# 2    4200                          Portal 2        2011-04-18         4.62
# 3    5286                Tomb Raider (2013)        2013-03-05         4.05
# 4    4291  Counter-Strike: Global Offensive        2012-08-21         3.56
#
#   game_metacritic game_playtime
# 0              92            73
# 1              92            46
# 2              95            11
# 3              86            10
# 4              81            65

# %%
#change values in game_id from int to string
df["game_id"] = df["game_id"].astype(str)

# %%
df["game_id"][1]
# Out:
# '3328'

# %%
#Check for null values in df
df.isnull().sum()
# Out:
# game_id                0
# game_name              0
# game_release_date      5
# game_rating            0
# game_metacritic      402
# game_playtime          0
# dtype: int64

# %%
def connect_to_db(host_name, dbname, port, username, password):
    try:
        conn = ps.connect(host=host_name, database=dbname, user=username, password=password, port=port)

    except ps.OperationalError as e:
        raise e
    else:
        print('Connected!')
        return conn

# %%
def delete_table(curr, table_name):
    delete_query = "DROP TABLE IF EXISTS {}".format(table_name)
    curr.execute(delete_query)

# %%
def create_table(curr):
    create_table_command = ("""CREATE TABLE IF NOT EXISTS games(
                                game_id VARCHAR(225),
                                game_name VARCHAR(225) NOT NULL,
                                game_release_date DATE Default NULL,
                                game_rating FLOAT NOT NULL,
                                game_metacritic INTEGER,
                                game_playtime INTEGER NOT NULL,
                                PRIMARY KEY ("game_id")
                                );""")

    curr.execute(create_table_command)

# %%
def check_if_game_exists(curr, game_id): 
    query = ("""SELECT game_id FROM games WHERE game_id = %s""")

    curr.execute(query, (game_id,))
    return curr.fetchone() is not None

# %%
def update_row(curr, game_id, game_name, game_release_date, game_rating, game_metacritic, game_playtime):
    query = ("""UPDATE games 
                SET game_name = %s, 
                    game_release_date = %s, 
                    game_rating = %s, 
                    game_metacritic = %s, 
                    game_playtime = %s 
                WHERE game_id = %s""")
    vars_to_insert = (game_id, game_name, game_release_date, game_rating, game_metacritic, game_playtime)
    curr.execute(query, vars_to_insert)

# %%
def update_db(curr, df):
    tmp_df = pd.DataFrame(columns=["game_id", "game_name", "game_release_date", "game_rating", 
                                   "game_metacritic","game_playtime"])
    for i, row in df.iterrows():
        if check_if_game_exists(curr, row['game_id']): # If video already exists then we will update
            update_row(curr,row['game_id'],row['game_name'],row['game_release_date'],row['game_rating'],
                           row['game_metacritic'],row['game_playtime'])
        else: # The video doesn't exists so we will add it to a temp df and append it using append_from_df_to_db
            tmp_df = tmp_df.append(row)

    return tmp_df

# %%
def append_from_df_to_db(curr,df):
    for i, row in df.iterrows():
        insert_into_table(curr, row['game_id'],row['game_name'],row['game_release_date'],row['game_rating'],
                               row['game_metacritic'],row['game_playtime'] )

# %%
def insert_into_table(curr, game_id, game_name, game_release_date, game_rating, game_metacritic, game_playtime):
    query = ("""INSERT INTO games (game_id, game_name, game_release_date, game_rating, game_metacritic, game_playtime) 
                VALUES (%s, %s, %s, %s, %s, %s)""")
    
    vars_to_insert = (game_id, game_name, game_release_date, game_rating, game_metacritic, game_playtime)
    curr.execute(query, vars_to_insert)

# %%
#get column names and store in variable column_names
column_names = df.columns.tolist()

# %%
column_names
# Out:
# ['game_id',
#  'game_name',
#  'game_release_date',
#  'game_rating',
#  'game_metacritic',
#  'game_playtime']

# %%
## Main
#database credentials

host_name = '--------------------'
dbname = '-----'
port = '5432'
username = '-----' 
password = '-----------'
conn = None

conn = connect_to_db(host_name, dbname, port, username, password)
curr = conn.cursor()
# Out:
# Connected!

# %%
delete_table(curr, "games")
conn.commit()

# %%
create_table(curr)
conn.commit()

# %%
#update data for existing videos

new_games_df = update_db(curr,df)
conn.commit()

# %%
new_games_df.head()
# Out:
#   game_id                         game_name game_release_date  game_rating  \
# 0    3498                Grand Theft Auto V        2013-09-17         4.47
# 1    3328          The Witcher 3: Wild Hunt        2015-05-18         4.66
# 2    4200                          Portal 2        2011-04-18         4.62
# 3    5286                Tomb Raider (2013)        2013-03-05         4.05
# 4    4291  Counter-Strike: Global Offensive        2012-08-21         3.56
#
#   game_metacritic game_playtime
# 0              92            73
# 1              92            46
# 2              95            11
# 3              86            10
# 4              81            65

# %%
#insert new videos into db table

append_from_df_to_db(curr, new_games_df)
conn.commit()

# %%
#view data in db table
"""curr.execute("SELECT * FROM games")
print(curr.fetchall())  """
# Out:
# 'curr.execute("SELECT * FROM games")\nprint(curr.fetchall())  '
